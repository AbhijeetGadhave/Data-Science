# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhijeetAlekar22/Data-Science/blob/main/Anova_and_Chisquare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anova

# %%
# Load libraries
from sklearn import datasets
import pandas as pd

# Load digits dataset
iris = datasets.load_iris()

# %%
df = pd.DataFrame(iris.data)

# %%
df
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
import scipy.stats as stats
stats.f_oneway(df.iloc[:,0], df.iloc[:,1],df.iloc[:,2],df.iloc[:,3])
# Out:
# F_onewayResult(statistic=482.91531656927964, pvalue=4.660592480454751e-159)
